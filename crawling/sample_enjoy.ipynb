# %%
import time
import re
import requests
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
from tqdm import tqdm
import pandas as pd
import googlemaps
import urllib.parse

station_list=['뚝섬역', '서촌', '강남역', '서울역', '해방촌', '수유역', '경복궁', '암사동 유적']

# KAKAO_API_KEY = "1a6063efba1d306ac8725b784b11fa13"
GOOGLE_API_KEY = "AIzaSyCtPF92it_bqVkfPKeKbKHmmo9ig2RyaPE"
results=[]

def switch_left():
    driver.switch_to.default_content()
    iframe = driver.find_element(By.XPATH, '//*[@id="searchIframe"]')
    driver.switch_to.frame(iframe)

def switch_right():
    driver.switch_to.default_content()
    iframe = driver.find_element(By.XPATH, '//*[@id="entryIframe"]')
    driver.switch_to.frame(iframe)

def clean_address(address):
    # # (우) 우편번호 제거
    # address = re.sub(r'\s*\(우\)\d{5}.*$', '', address)

    # # 쉼표 또는 하이픈으로 구분된 '층' 관련 정보 제거
    # address = re.sub(r'[,/-]?\s*\d+[\-,\d]*\s*층.*$', '', address)  # 예: , 1층 / 1,2층 / 1-2층
    # address = re.sub(r'[,/-]?\s*\d+\s*호.*$', '', address)          # 예: , 101호

    # # 도로명 주소만 추출 (길 포함 가능)
    # match = re.search(r'([가-힣\d\s\-]*로\d*(길\s?\d+)?\s?\d*)', address)
    # address = match.group(0) if match else address.strip()

    return address.strip()

def extract_number(text):
    match = re.search(r'\d+', text.replace(',', ''))
    return int(match.group(0)) if match else 0

def get_lat_lon(address):

    gmaps = googlemaps.Client(key=GOOGLE_API_KEY)
    geocode = gmaps.geocode(address=address)
    lat = geocode[0].get("geometry")["location"]["lat"]
    lon = geocode[0].get("geometry")["location"]["lng"]

    # time.sleep(1)
    # url = f"https://dapi.kakao.com/v2/local/search/address.json?query={address}"
    # headers = {"Authorization": f"KakaoAK {KAKAO_API_KEY}"}
    # response = requests.get(url, headers=headers)

    # if response.status_code == 429:
    #     time.sleep(60)
    #     return get_lat_lon(address)

    # result = response.json()
    # if "documents" not in result or not result["documents"]:
    #     return None, None

    # match_first = result["documents"][0]["address"]
    # lat = float(match_first["y"])
    # lon = float(match_first["x"])
    return lat, lon


# Selenium 설정
options = webdriver.ChromeOptions()
options.add_argument('user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3')
options.add_argument('window-size=1380,900')
driver = webdriver.Chrome(options=options)
driver.implicitly_wait(3)

for place in station_list:
    search_url = f"https://map.naver.com/p/search/{urllib.parse.quote(place + ' 놀거리')}"
    driver.get(search_url)
    time.sleep(3)

    try:
        WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//*[@id="searchIframe"]')))
        switch_left()
    except:
        print(f"[{place}] 검색결과 없음 - 스킵")
        continue

    try:
        scrollable_element = WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.ID, "_pcmap_list_scroll_container"))
        )
    except Exception as e:
        print(f"[{place}] 스크롤 요소 탐색 실패: {e} - 스킵")
        continue

    # 스크롤 내리기
    scroll_pause_time = 1
    max_scroll_attempts = 30
    last_height = driver.execute_script("return arguments[0].scrollHeight", scrollable_element)

    for _ in range(max_scroll_attempts):
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scrollable_element)
        time.sleep(scroll_pause_time)
        new_height = driver.execute_script("return arguments[0].scrollHeight", scrollable_element)
        if new_height == last_height:
            break
        last_height = new_height

    elements = driver.find_elements(By.XPATH, '//*[@id="_pcmap_list_scroll_container"]//li')

    for index, element in enumerate(elements):
        try:
            switch_left()
            clickable = element.find_element(By.CLASS_NAME, 'YgcU0')
            clickable.click()
            time.sleep(2)
        except:
            print(f"{index+1}번째 장소 클릭 실패")
            continue

        try:
            switch_right()
            time.sleep(2)

            soup = BeautifulSoup(driver.page_source, "html.parser")

            title = soup.find("div", class_="LylZZ v8v5j")
            store_name = title.find("span", class_="GHAhO").get_text(strip=True) if title else "놀거리명 없음"

             # 놀거리명 제외
            exclude_names = ["놀거리명 없음"]

            if store_name in exclude_names:
                continue

            category = title.find("span", class_="lnJFt").get_text(strip=True) if title else "카테고리 없음"

            # 일부 카테고리 제외
            exclude_categories = ["카테고리 없음", "카페,디저트", "일식당", "양식", "한식", "샤브샤브", "중식당", "이자카야", "베이커리", "요리주점", "베트남음식",
                                  "브런치", "카페", "햄버거", "양꼬치", "스파게티,파스타전문", "우동,소바", "멕시코,남미음식", "오니기리", "피자", "치킨,닭강정", "고기뷔페",
                                  "스터디카페", "초콜릿전문점", "소고기구이", "곱창,막창,양", "백숙,삼계탕", "막국수", "이탈리아음식", "아이스크림", "일본식라면"]

            if category in exclude_categories:
                continue

            visitor_review_element = soup.find("a", string=lambda text: text and "방문자 리뷰" in text)
            visitor_review = extract_number(visitor_review_element.get_text(strip=True)) if visitor_review_element else 0

            blog_review_element = soup.find("a", string=lambda text: text and "블로그 리뷰" in text)
            blog_review = extract_number(blog_review_element.get_text(strip=True)) if blog_review_element else 0

            total_reviews = visitor_review + blog_review

            address_element = soup.find("span", class_="LDgIH")
            address = clean_address(address_element.get_text(strip=True)) if address_element else "주소 없음"

            lat, lon = get_lat_lon(address)

            print(f"\n[지역: {place}] {index+1}. {store_name} · {category}")
            print(f"리뷰 수: {total_reviews}")
            print(f"주소: {address}")
            print(f"위도: {lat}, 경도: {lon}")
            print("-" * 50)

            results.append({
                "name": store_name,
                "station": place,
                "category" : category,
                "review": total_reviews,
                "address": address,
                "latitude": lat,
                "longitude": lon
            })

            # mycursor.execute("""
            #     INSERT INTO enjoy
            #     VALUES(%s, %s, %s, %s, %s, %s, %s)
            # """, (store_name, place, total_reviews, address, lat, lon))
            # ojk.commit()

        except Exception as ex:
            print(f"{index+1}번째 장소 정보 수집 실패: {ex}")
            print("-" * 50)
            continue

driver.quit()
df = pd.DataFrame(results)
df.to_csv('sample_enjoy_results.csv', index=False, encoding='utf-8-sig')
print("CSV 저장 완료: sample_enjoy_results.csv")
# Out:
# [지역: 뚝섬역] 1. 뚝섬미술관 · 미술관
# 리뷰 수: 8608
# 주소: 서울 성동구 아차산로 33 지하 1층
# 위도: 37.547351, 경도: 127.0484429
# --------------------------------------------------
#
# [지역: 뚝섬역] 4. 섬세이 테라리움 · 전시관
# 리뷰 수: 5077
# 주소: 서울 성동구 서울숲2길 44-1 지하1층 섬세이 테라리움
# 위도: 37.5462075, 경도: 127.0435608
# --------------------------------------------------
#
# [지역: 뚝섬역] 6. 성수아트홀 · 공연장
# 리뷰 수: 1001
# 주소: 서울 성동구 뚝섬로1길 43
# 위도: 37.5454156, 경도: 127.0469729
# --------------------------------------------------
#
# [지역: 뚝섬역] 9. 무비랜드 · 영화관
# 리뷰 수: 293
# 주소: 서울 성동구 연무장길 5-5
# 위도: 37.5441644, 경도: 127.0502997
# --------------------------------------------------
#
# [지역: 뚝섬역] 11. 인더무드성수 셀프사진관 · 셀프,대여스튜디오
# 리뷰 수: 146
# 주소: 서울 성동구 왕십리로16가길 10 지하1층
# 위도: 37.5503473, 경도: 127.0448514
# --------------------------------------------------
#
# [지역: 뚝섬역] 12. 라쿵 베이커리 · 공방
# 리뷰 수: 71
# 주소: 서울 성동구 아차산로 54 4층
# 위도: 37.54612729999999, 경도: 127.0500548
# --------------------------------------------------
#
# [지역: 뚝섬역] 13. 컬러온스튜디오 · 공방
# 리뷰 수: 736
# 주소: 서울 성동구 왕십리로10길 20 2층
# 위도: 37.54647380000001, 경도: 127.0466892
# --------------------------------------------------
#
# [지역: 뚝섬역] 14. 유유히 성수 · 공방
# 리뷰 수: 2323
# 주소: 서울 성동구 서울숲9길 5 101호
# 위도: 37.5483984, 경도: 127.0435731
# --------------------------------------------------
#
# [지역: 뚝섬역] 16. 히포캠퍼스 성수 · 공방
# 리뷰 수: 2623
# 주소: 서울 성동구 성수일로12길 19-1 B1층
# 위도: 37.5484304, 경도: 127.0534454
# --------------------------------------------------
#
# [지역: 뚝섬역] 17. 코사이어티 · 복합문화공간
# 리뷰 수: 1325
# 주소: 서울 성동구 왕십리로 82-20 코사이어티
# 위도: 37.5447703, 경도: 127.0456715
# --------------------------------------------------
#
# [지역: 뚝섬역] 20. 스냅파이 서울숲 · 셀프,대여스튜디오
# 리뷰 수: 123
# 주소: 서울 성동구 서울숲2길 24
# 위도: 37.5468084, 경도: 127.0414045
# --------------------------------------------------
#
# [지역: 뚝섬역] 21. 더서울라이티움 · 전시관
# 리뷰 수: 136
# 주소: 서울 성동구 서울숲2길 32-14 갤러리아포레 지2층
# 위도: 37.545702, 경도: 127.042425
# --------------------------------------------------
#
# [지역: 뚝섬역] 22. 낫저스트북스 · 독립서점
# 리뷰 수: 138
# 주소: 서울 성동구 서울숲길 44 3층
# 위도: 37.547883, 경도: 127.0423843
# --------------------------------------------------
#
# [지역: 뚝섬역] 23. 더페이지갤러리 · 갤러리,화랑
# 리뷰 수: 1207
# 주소: 서울 성동구 서울숲2길 32-14 갤러리아 포레 G205
# 위도: 37.545702, 경도: 127.042425
# --------------------------------------------------
#
# [지역: 뚝섬역] 24. 너즐 · 고양이카페
# 리뷰 수: 222
# 주소: 서울 성동구 서울숲6길 14 거암아트빌라 4층
# 위도: 37.5475077, 경도: 127.0430577
# --------------------------------------------------
#
# [지역: 뚝섬역] 26. 보드게임카페 레드버튼 성수점 · 보드카페
# 리뷰 수: 1393
# 주소: 서울 성동구 연무장길 17 3층
# 위도: 37.54374749999999, 경도: 127.0514862
# --------------------------------------------------
#
# [지역: 뚝섬역] 27. 플라비 성수점 · 공방
# 리뷰 수: 1174
# 주소: 서울 성동구 서울숲2길 19-17 반지하층
# 위도: 37.5474204, 경도: 127.0410508
# --------------------------------------------------
#
# [지역: 뚝섬역] 28. 성동구민종합체육센터 · 구민체육센터
# 리뷰 수: 676
# 주소: 서울 성동구 왕십리로 89
# 위도: 37.54575579999999, 경도: 127.0440944
# --------------------------------------------------
#
# [지역: 뚝섬역] 33. 디뮤지엄 · 미술관
# 리뷰 수: 13577
# 주소: 서울 성동구 왕십리로 83-21 디뮤지엄
# 위도: 37.5438189, 경도: 127.0441812
# --------------------------------------------------
#
# [지역: 뚝섬역] 34. 블루밍테라 · 관람,체험
# 리뷰 수: 44
# 주소: 서울 성동구 아차산로 6 1층
# 위도: 37.5463387, 경도: 127.0535209
# --------------------------------------------------
#
# [지역: 뚝섬역] 35. 플레이즈라운지 · 키즈카페,실내놀이터
# 리뷰 수: 2521
# 주소: 서울 성동구 서울숲2길 32-14 갤러리아포레 더몰 B104
# 위도: 37.545702, 경도: 127.042425
# --------------------------------------------------
#
# [지역: 뚝섬역] 36. 모노맨션 성수점 · 셀프,대여스튜디오
# 리뷰 수: 58
# 주소: 서울 성동구 연무장길 30 1층
# 위도: 37.5431008, 경도: 127.0527908
# --------------------------------------------------
#
# [지역: 뚝섬역] 38. 서울숲복합문화체육센터 · 구민체육센터
# 리뷰 수: 1285
# 주소: 서울 성동구 왕십리로11길 19
# 위도: 37.5496222, 경도: 127.0428282
# --------------------------------------------------
#
# [지역: 뚝섬역] 42. 레트르 성수 · 공방
# 리뷰 수: 12135
# 주소: 서울 성동구 연무장길 37-18 1층
# 위도: 37.5433702, 경도: 127.0537867
# --------------------------------------------------
#
# [지역: 뚝섬역] 43. 레토 성수 · 방탈출카페
# 리뷰 수: 392
# 주소: 서울 성동구 연무장5길 18 지하1층 101호
# 위도: 37.544559, 경도: 127.0531701
# --------------------------------------------------
#
# [지역: 뚝섬역] 44. 성수 웯우드스튜디오 나무반지공방 · 공방
# 리뷰 수: 293
# 주소: 서울 성동구 연무장5가길 7 1층 131호
# 위도: 37.5440369, 경도: 127.0536291
# --------------------------------------------------
#
# [지역: 뚝섬역] 45. 클라쎄 성수 · 공방
# 리뷰 수: 2499
# 주소: 서울 성동구 연무장5가길 7 성수역 현대테라스타워 1층 130호
# 위도: 37.5439435, 경도: 127.0532314
# --------------------------------------------------
#
# [지역: 뚝섬역] 47. 위에트 성수 · 공방
# 리뷰 수: 1122
# 주소: 서울 성동구 서울숲2길 8-8 3층
# 위도: 37.5472477, 경도: 127.0394561
# --------------------------------------------------
#
# [지역: 뚝섬역] 48. 언더스탠드에비뉴 · 복합문화공간
# 리뷰 수: 3091
# 주소: 서울 성동구 왕십리로 63 언더스탠드에비뉴
# 위도: 37.5436067, 경도: 127.0436433
# --------------------------------------------------
#
# [지역: 뚝섬역] 50. 오브유 · 공방
# 리뷰 수: 375
# 주소: 서울 성동구 왕십리로 66-33 2층
# 위도: 37.5430007, 경도: 127.0454699
# --------------------------------------------------
#
# [지역: 서촌] 1. 그라운드시소 서촌 · 복합문화공간
# 리뷰 수: 14083
# 주소: 서울 종로구 자하문로6길 18-8
# 위도: 37.5778413, 경도: 126.9729057
# --------------------------------------------------
#
# [지역: 서촌] 2. 대림미술관 · 미술관
# 리뷰 수: 14103
# 주소: 서울 종로구 자하문로4길 21 대림미술관
# 위도: 37.5775023, 경도: 126.9733626
# --------------------------------------------------
#
# [지역: 서촌] 3. onground · 갤러리,화랑
# 리뷰 수: 1873
# 주소: 서울 종로구 자하문로10길 23
# 위도: 37.5795215, 경도: 126.9727876
# --------------------------------------------------
#
# [지역: 서촌] 4. 통의동 보안여관 · 갤러리,화랑
# 리뷰 수: 1269
# 주소: 서울 종로구 효자로 33
# 위도: 37.57904389999999, 경도: 126.9736188
# --------------------------------------------------
#
# [지역: 서촌] 5. 리안갤러리 서울 · 갤러리,화랑
# 리뷰 수: 233
# 주소: 서울 종로구 자하문로12길 9
# 위도: 37.5798204, 경도: 126.9719442
# --------------------------------------------------
#
# [지역: 서촌] 6. 경복궁아트홀 · 공연,연극시설
# 리뷰 수: 27
# 주소: 서울 종로구 자하문로 82 경복궁아트홀
# 위도: 37.5833524, 경도: 126.9706979
# --------------------------------------------------
#
# [지역: 서촌] 7. 종로구립 박노수미술관 · 미술관
# 리뷰 수: 797
# 주소: 서울 종로구 옥인1길 34
# 위도: 37.5813669, 경도: 126.9667492
# --------------------------------------------------
#
# [지역: 서촌] 8. 아트사이드 갤러리 · 갤러리,화랑
# 리뷰 수: 656
# 주소: 서울 종로구 자하문로6길 15 아트사이드 갤러리
# 위도: 37.5782277, 경도: 126.9729419
# --------------------------------------------------
#
# [지역: 서촌] 9. 이이엄 · 복합문화공간
# 리뷰 수: 56
# 주소: 서울 종로구 필운대로9길 3 1~2층
# 위도: 37.5821709, 경도: 126.9674787
# --------------------------------------------------
#
# [지역: 서촌] 10. 서촌라운지 · 복합문화공간
# 리뷰 수: 104
# 주소: 서울 종로구 필운대로 27-4
# 위도: 37.5784977, 경도: 126.9688875
# --------------------------------------------------
#
# [지역: 서촌] 11. 갤러리 B · 갤러리,화랑
# 리뷰 수: 122
# 주소: 서울 종로구 자하문로7길 5
# 위도: 37.5781613, 경도: 126.9712751
# --------------------------------------------------
#
# [지역: 서촌] 12. 어피스어피스 · 전시관
# 리뷰 수: 39
# 주소: 서울 종로구 필운대로 48 4층
# 위도: 37.5803124, 경도: 126.9687687
# --------------------------------------------------
#
# [지역: 서촌] 13. 플루리포텐트 아트 스페이스 · 복합문화공간
# 리뷰 수: 8
# 주소: 서울 종로구 효자로9길 30 지층 101호(창성동)
# 위도: 37.5804775, 경도: 126.9730136
# --------------------------------------------------
#
# [지역: 서촌] 14. 갤러리 그리다 · 갤러리,화랑
# 리뷰 수: 14
# 주소: 서울 종로구 자하문로12길 21
# 위도: 37.5802665, 경도: 126.972048
# --------------------------------------------------
#
# [지역: 서촌] 15. 아트스페이스서촌 · 갤러리,화랑
# 리뷰 수: 13
# 주소: 서울 종로구 자하문로10길 7 1층, 지하1층
# 위도: 37.5796218, 경도: 126.9719007
# --------------------------------------------------
#
# [지역: 서촌] 16. 진화랑 · 갤러리,화랑
# 리뷰 수: 142
# 주소: 서울 종로구 효자로 25
# 위도: 37.5783286, 경도: 126.9736927
# --------------------------------------------------
#
# [지역: 서촌] 17. 메종드그루 · 복합문화공간
# 리뷰 수: 299
# 주소: 서울 종로구 효자로 37
# 위도: 37.5792783, 경도: 126.9736755
# --------------------------------------------------
#
# [지역: 서촌] 18. 가진화랑 · 갤러리,화랑
# 리뷰 수: 88
# 주소: 서울 종로구 자하문로 74
# 위도: 37.5825139, 경도: 126.9708972
# --------------------------------------------------
#
# [지역: 서촌] 20. 공간서로 · 공연장
# 리뷰 수: 6
# 주소: 서울 종로구 필운대로7길 12 1F, B1
# 위도: 37.5815867, 경도: 126.9678759
# --------------------------------------------------
#
# [지역: 서촌] 22. 세컨드뮤지엄 · 복합문화공간
# 리뷰 수: 26
# 주소: 서울 종로구 자하문로17길 12-24
# 위도: 37.5824359, 경도: 126.9696193
# --------------------------------------------------
#
# [지역: 서촌] 23. 서촌재 · 갤러리,화랑
# 리뷰 수: 5
# 주소: 서울 종로구 옥인길 65
# 위도: 37.5816155, 경도: 126.9652535
# --------------------------------------------------
#
# [지역: 서촌] 24. 갤러리 291 · 갤러리,화랑
# 리뷰 수: 19
# 주소: 서울 종로구 옥인3길 14 201호
# 위도: 37.5808, 경도: 126.9660287
# --------------------------------------------------
#
# [지역: 서촌] 26. 서촌창작소 · 복합문화공간
# 리뷰 수: 10
# 주소: 서울 종로구 자하문로9길 24 2층
# 위도: 37.579581, 경도: 126.9697597
# --------------------------------------------------
#
# [지역: 서촌] 29. 이상의집 · 문화,유적
# 리뷰 수: 364
# 주소: 서울 종로구 자하문로7길 18
# 위도: 37.5786466, 경도: 126.9708668
# --------------------------------------------------
#
# [지역: 서촌] 31. 사진위주 류가헌 갤러리 · 갤러리,화랑
# 리뷰 수: 457
# 주소: 서울 종로구 자하문로 106 아카이브빌딩 2층 지하1층
# 위도: 37.5853679, 경도: 126.9703607
# --------------------------------------------------
#
# [지역: 서촌] 33. 통인시장 · 시장
# 리뷰 수: 4101
# 주소: 서울 종로구 자하문로15길 18
# 위도: 37.5807689, 경도: 126.969948
# --------------------------------------------------
#
# [지역: 서촌] 44. 책방오늘 · 독립서점
# 리뷰 수: 477
# 주소: 서울 종로구 자하문로6길 11 1호
# 위도: 37.5781982, 경도: 126.972777
# --------------------------------------------------
#
# [지역: 서촌] 48. 위에트 서촌 · 공방
# 리뷰 수: 317
# 주소: 서울 종로구 자하문로 37-1 1동 3층
# 위도: 37.5793824, 경도: 126.9711048
# --------------------------------------------------
#
# [지역: 강남역] 1. 제로월드 강남점 · 방탈출카페
# 리뷰 수: 3531
# 주소: 서울 서초구 서초대로73길 40 지하1층
# 위도: 37.5009346, 경도: 127.0245823
# --------------------------------------------------
#
# [지역: 강남역] 2. 코드케이 방탈출카페 · 방탈출카페
# 리뷰 수: 2164
# 주소: 서울 강남구 봉은사로2길 31 지하 1층 코드케이
# 위도: 37.5026457, 경도: 127.0263524
# --------------------------------------------------
#
# [지역: 강남역] 3. 세븐클루스 강남 2호점 · 방탈출카페
# 리뷰 수: 1648
# 주소: 서울 강남구 강남대로 432 점프밀라노 7층 704호 세븐클루스
# 위도: 37.5012754, 경도: 127.0265365
# --------------------------------------------------
#
# [지역: 강남역] 4. 벌툰 엔틱 강남역점 · 만화방
# 리뷰 수: 940
# 주소: 서울 강남구 강남대로98길 16 3층
# 위도: 37.5007047, 경도: 127.0280292
# --------------------------------------------------
#
# [지역: 강남역] 5. 비트포비아 강남던전 · 방탈출카페
# 리뷰 수: 1971
# 주소: 서울 강남구 강남대로84길 33 대우디오빌플러스 지하1층 111호
# 위도: 37.497514, 경도: 127.0310602
# --------------------------------------------------
#
# [지역: 강남역] 6. 보드게임카페 레드버튼 시네마강남 · 보드카페
# 리뷰 수: 3206
# 주소: 서울 강남구 강남대로 422 4층, 5층
# 위도: 37.5003747, 경도: 127.0269158
# --------------------------------------------------
#
# [지역: 강남역] 7. 엑소더스 강남1호점 · 방탈출카페
# 리뷰 수: 617
# 주소: 서울 강남구 봉은사로18길 80 지하1층 엑소더스 강남1호점
# 위도: 37.5015977, 경도: 127.0273217
# --------------------------------------------------
#
# [지역: 강남역] 8. 벌툰 파리지앵 강남본점 · 만화방
# 리뷰 수: 248
# 주소: 서울 서초구 강남대로65길 7 3층 만화카페 벌툰
# 위도: 37.50027559999999, 경도: 127.0253266
# --------------------------------------------------
#
# [지역: 강남역] 9. 세븐클루스 강남1호점 · 방탈출카페
# 리뷰 수: 873
# 주소: 서울 강남구 테헤란로2길 8 동일빌딩 지하1층
# 위도: 37.4976012, 경도: 127.0287219
# --------------------------------------------------
#
# [지역: 강남역] 10. 황금열쇠 플라워로드 강남 · 방탈출카페
# 리뷰 수: 554
# 주소: 서울 강남구 봉은사로18길 76 4층
# 위도: 37.5017923, 경도: 127.0273977
# --------------------------------------------------
#
# [지역: 강남역] 11. 키이스케이프 메모리컴퍼니 · 방탈출카페
# 리뷰 수: 1455
# 주소: 서울 강남구 봉은사로2길 7 지하1층
# 위도: 37.5042376, 경도: 127.0256463
# --------------------------------------------------
#
# [지역: 강남역] 12. 퍼퓸플레이 강남 · 공방
# 리뷰 수: 1536
# 주소: 서울 강남구 테헤란로 101 지하2층
# 위도: 37.4986087, 경도: 127.0278979
# --------------------------------------------------
#
# [지역: 강남역] 13. 세모네모동그라미 · 공방
# 리뷰 수: 592
# 주소: 서울 강남구 강남대로106길 14 오성빌딩 3층
# 위도: 37.5029028, 경도: 127.0266662
# --------------------------------------------------
#
# [지역: 강남역] 14. 반지대학 강남캠퍼스 · 공방
# 리뷰 수: 792
# 주소: 서울 강남구 테헤란로1길 32 연성흠근생 4층 1호
# 위도: 37.5004222, 경도: 127.0274685
# --------------------------------------------------
#
# [지역: 강남역] 15. 물감아트클래스 강남 · 공방
# 리뷰 수: 1069
# 주소: 서울 서초구 강남대로61길 19 대우벨라채 508호
# 위도: 37.4985124, 경도: 127.0247111
# --------------------------------------------------
#
# [지역: 강남역] 16. 레미니스 퍼퓸 · 공방
# 리뷰 수: 761
# 주소: 서울 서초구 서초대로77길 3 아라타워 8층
# 위도: 37.4979437, 경도: 127.0265374
# --------------------------------------------------
#
# [지역: 강남역] 17. 아트마스 스튜디오 · 공방
# 리뷰 수: 142
# 주소: 서울 서초구 강남대로 381 두산베어스텔 606호
# 위도: 37.4967849, 경도: 127.0276423
# --------------------------------------------------
#
# [지역: 강남역] 18. 강남역 흑백 셀프사진관 데이트코스 오디티모드 · 셀프,대여스튜디오
# 리뷰 수: 12659
# 주소: 서울 서초구 강남대로 455 지하 1층 120호
# 위도: 37.5028472, 경도: 127.0245444
# --------------------------------------------------
#
# [지역: 강남역] 19. 로빈훗 · 양궁장
# 리뷰 수: 304
# 주소: 서울 강남구 강남대로110길 13 B1
# 위도: 37.5040964, 경도: 127.0258517
# --------------------------------------------------
#
# [지역: 강남역] 21. 국립어린이청소년도서관 · 도서관
# 리뷰 수: 1159
# 주소: 서울 강남구 테헤란로7길 21 국립어린이청소년도서관
# 위도: 37.5008695, 경도: 127.0296393
# --------------------------------------------------
#
# [지역: 강남역] 25. 스머프 매직 포레스트 강남점 · 테마파크
# 리뷰 수: 1070
# 주소: 서울 강남구 강남대로106길 29 지하1층
# 위도: 37.5035148, 경도: 127.0278264
# --------------------------------------------------
#
# [지역: 강남역] 28. 고베규카츠 서울 강남점 · 돈가스
# 리뷰 수: 14494
# 주소: 서울 강남구 강남대로102길 29 예촌빌딩
# 위도: 37.502942, 경도: 127.0275891
# --------------------------------------------------
#
# [지역: 강남역] 31. 트라가 강남역점 · 스페인음식
# 리뷰 수: 16921
# 주소: 서울 서초구 강남대로55길 24 2층 201호 트라가
# 위도: 37.4956618, 경도: 127.0255981
# --------------------------------------------------
#
# [지역: 강남역] 36. 플랫나인 · 바(BAR)
# 리뷰 수: 3930
# 주소: 서울 서초구 강남대로65길 10 5층
# 위도: 37.50051000000001, 경도: 127.0249597
# --------------------------------------------------
#
# [지역: 강남역] 40. 성인취미미술학원 아트아뜰리에 강남점 · 미술교육
# 리뷰 수: 1034
# 주소: 서울 강남구 봉은사로4길 36 4층 402호
# 위도: 37.5024963, 경도: 127.0268427
# --------------------------------------------------
#
# [지역: 강남역] 41. 시사쿡요리아카데미 · 요리교육
# 리뷰 수: 1279
# 주소: 서울 강남구 테헤란로4길 28 송민빌딩 14층
# 위도: 37.4965132, 경도: 127.0300705
# --------------------------------------------------
#
# [지역: 강남역] 42. LP댄스학원 · 댄스교육
# 리뷰 수: 1831
# 주소: 서울 강남구 테헤란로5길 11 4층 LP댄스
# 위도: 37.4995267, 경도: 127.0292602
# --------------------------------------------------
#
# [지역: 강남역] 43. 한솔요리학원 강남점 · 요리교육
# 리뷰 수: 2446
# 주소: 서울 서초구 강남대로 405 통영빌딩 14층
# 위도: 37.4987358, 경도: 127.0266779
# --------------------------------------------------
#
# [지역: 강남역] 44. 뮤라벨 성인전문음악학원 강남본원 · 피아노
# 리뷰 수: 533
# 주소: 서울 강남구 강남대로94길 9 4층
# 위도: 37.4994846, 경도: 127.0280991
# --------------------------------------------------
#
# [지역: 강남역] 45. 에버라틴댄스A학원 · 댄스교육
# 리뷰 수: 434
# 주소: 서울 강남구 테헤란로6길 9 장원빌딩 라틴
# 위도: 37.4980087, 경도: 127.0307745
# --------------------------------------------------
#
# [지역: 강남역] 46. 이룸에이트 방탈출카페 · 방탈출카페
# 리뷰 수: 2854
# 주소: 서울 강남구 봉은사로 115 노벨테크빌딩 B2F
# 위도: 37.5052654, 경도: 127.026161
# --------------------------------------------------
#
# [지역: 강남역] 47. 오하운폴댄스학원 강남점 · 댄스교육
# 리뷰 수: 942
# 주소: 서울 강남구 봉은사로6길 34 스타제이빌딩 3층, 4층
# 위도: 37.502838, 경도: 127.027394
# --------------------------------------------------
#
# [지역: 서울역] 1. 그라운드시소 센트럴 · 전시관
# 리뷰 수: 5529
# 주소: 서울 중구 세종대로 14 그랜드센트럴 3F
# 위도: 37.557877, 경도: 126.9743793
# --------------------------------------------------
#
# [지역: 서울역] 2. 문화역서울284 · 복합문화공간
# 리뷰 수: 9168
# 주소: 서울 중구 통일로 1 문화역서울284
# 위도: 37.5558824, 경도: 126.9715573
# --------------------------------------------------
#
# [지역: 서울역] 3. 동자아트홀 · 공연장
# 리뷰 수: 48
# 주소: 서울 용산구 한강대로 372 45 KDB생명타워 B2층
# 위도: 37.5515841, 경도: 126.9728797
# --------------------------------------------------
#
# [지역: 서울역] 5. 서소문성지역사박물관 · 박물관
# 리뷰 수: 2526
# 주소: 서울 중구 칠패로 5
# 위도: 37.5605524, 경도: 126.96935
# --------------------------------------------------
#
# [지역: 서울역] 8. 스페이스후암23 · 갤러리,화랑
# 리뷰 수: 43
# 주소: 서울 용산구 후암로 23 space huam23
# 위도: 37.5478492, 경도: 126.9777478
# --------------------------------------------------
#
# [지역: 서울역] 9. KP Gallery · 갤러리,화랑
# 리뷰 수: 30
# 주소: 서울 용산구 소월로2나길 12
# 위도: 37.5533283, 경도: 126.9773127
# --------------------------------------------------
#
# [지역: 서울역] 11. 스튜디오코드 · 셀프,대여스튜디오
# 리뷰 수: 46
# 주소: 서울 중구 만리재로 217
# 위도: 37.5568928, 경도: 126.968192
# --------------------------------------------------
#
# [지역: 서울역] 14. 글루넛 가죽작업실 · 공방
# 리뷰 수: 287
# 주소: 서울 용산구 후암로13길 36 1층(후암동)
# 위도: 37.5465893, 경도: 126.9778234
# --------------------------------------------------
#
# [지역: 서울역] 17. 세라믹스튜디오 이내 · 공방
# 리뷰 수: 59
# 주소: 서울 용산구 한강대로102가길 10-1 1층
# 위도: 37.5491302, 경도: 126.973101
# --------------------------------------------------
#
# [지역: 서울역] 18. 구립청파도서관 · 도서관
# 리뷰 수: 64
# 주소: 서울 용산구 청파로93길 27
# 위도: 37.5539424, 경도: 126.9675804
# --------------------------------------------------
#
# [지역: 서울역] 19. GDR+아카데미 실로암점 · 실내골프연습장
# 리뷰 수: 747
# 주소: 서울 중구 중림로 49 실로암빌딩 지하 1층
# 위도: 37.5577318, 경도: 126.9686026
# --------------------------------------------------
#
# [지역: 서울역] 21. 에오디에 · 공방
# 리뷰 수: 15
# 주소: 서울 용산구 후암로13길 4 1층
# 위도: 37.5480011, 경도: 126.977618
# --------------------------------------------------
#
# [지역: 서울역] 23. 기막힌셀프스튜디오 셀프사진관 · 셀프,대여스튜디오
# 리뷰 수: 185
# 주소: 서울 용산구 청파로71길 32 지하 1층 기막힌스튜디오
# 위도: 37.5497062, 경도: 126.9683043
# --------------------------------------------------
#
# [지역: 서울역] 26. GDR아카데미 용산서울역점 · 실내골프연습장
# 리뷰 수: 1111
# 주소: 서울 용산구 한강대로 366 트윈시티 남산 B2 GDR아카데미 용산 서울역점
# 위도: 37.5507383, 경도: 126.9727203
# --------------------------------------------------
#
# [지역: 서울역] 27. 샤워 · 갤러리,화랑
# 리뷰 수: 8
# 주소: 서울 용산구 두텁바위로 61 지층
# 위도: 37.5461908, 경도: 126.9790845
# --------------------------------------------------
#
# [지역: 서울역] 28. 마이트리 GDR 아카데미 시청점 · 실내골프연습장
# 리뷰 수: 319
# 주소: 서울 중구 칠패로 27 지하2층
# 위도: 37.5601765, 경도: 126.9720654
# --------------------------------------------------
#
# [지역: 서울역] 29. 플러스준스튜디오 용산 · 셀프,대여스튜디오
# 리뷰 수: 328
# 주소: 서울 용산구 한강대로98가길 7
# 위도: 37.5480011, 경도: 126.9732436
# --------------------------------------------------
#
# [지역: 서울역] 30. 얼스오브제 · 공방
# 리뷰 수: 116
# 주소: 서울 용산구 만리재로 186 2층
# 위도: 37.5543264, 경도: 126.9668479
# --------------------------------------------------
#
# [지역: 서울역] 34. 서울시립미술관 · 미술관
# 리뷰 수: 13976
# 주소: 서울 중구 덕수궁길 61
# 위도: 37.5643082, 경도: 126.9744408
# --------------------------------------------------
#
# [지역: 서울역] 38. 해랑스시 · 초밥,롤
# 리뷰 수: 2778
# 주소: 서울 중구 통일로 10 연세세브란스빌딩 지하1층 해랑스시
# 위도: 37.5570572, 경도: 126.9736211
# --------------------------------------------------
#
# [지역: 서울역] 42. 도쿄스테이크 서울스퀘어점 · 스테이크,립
# 리뷰 수: 3372
# 주소: 서울 중구 한강대로 416
# 위도: 37.5555215, 경도: 126.9738608
# --------------------------------------------------
#
# [지역: 서울역] 44. 라탄공방 슬로우위캔드 · 공방
# 리뷰 수: 18
# 주소: 서울 용산구 소월로2길 11 3층
# 위도: 37.5544952, 경도: 126.9767447
# --------------------------------------------------
#
# [지역: 서울역] 45. 동서골프프라자 · 실외골프연습장
# 리뷰 수: 288
# 주소: 서울 용산구 청파로 314
# 위도: 37.5476211, 경도: 126.9706012
# --------------------------------------------------
#
# [지역: 서울역] 47. 놉스 서울역점 · 스테이크,립
# 리뷰 수: 822
# 주소: 서울 중구 세종대로 14 2층 201호
# 위도: 37.557877, 경도: 126.9743793
# --------------------------------------------------
#
# [지역: 해방촌] 7. 갤러리 더 스퀘어 용산점 · 차
# 리뷰 수: 71
# 주소: 서울 용산구 신흥로 103-1 2층
# 위도: 37.54478460000001, 경도: 126.9844845
# --------------------------------------------------
#
# [지역: 해방촌] 11. 오드 프레젠트 · 영화관
# 리뷰 수: 78
# 주소: 서울 용산구 소월로20길 53
# 위도: 37.54424290000001, 경도: 126.984683
# --------------------------------------------------
#
# [지역: 해방촌] 12. 상히읗 · 갤러리,화랑
# 리뷰 수: 18
# 주소: 서울 용산구 신흥로 30 지하 02호
# 위도: 37.5410461, 경도: 126.9872407
# --------------------------------------------------
#
# [지역: 해방촌] 13. TTD · 공방
# 리뷰 수: 4
# 주소: 서울 용산구 신흥로11나길 2-27
# 위도: 37.5440638, 경도: 126.9858941
# --------------------------------------------------
#
# [지역: 해방촌] 16. 감정선프로젝트 이태원본점 · 공방
# 리뷰 수: 476
# 주소: 서울 용산구 회나무로 7 지하1층 감정선프로젝트 이태원본점
# 위도: 37.5386414, 경도: 126.987676
# --------------------------------------------------
#
# [지역: 해방촌] 17. 카마라타뮤직컴퍼니 · 공연,연극시설
# 리뷰 수: 47
# 주소: 서울 용산구 신흥로7길 1
# 위도: 37.5419221, 경도: 126.9871708
# --------------------------------------------------
#
# [지역: 해방촌] 18. 인프로그레스 · 독립서점
# 리뷰 수: 45
# 주소: 서울 용산구 신흥로20길 35 지하 1층
# 위도: 37.5470704, 경도: 126.9839278
# --------------------------------------------------
#
# [지역: 해방촌] 19. 콤콤오락실 이태원점 · 오락실
# 리뷰 수: 13
# 주소: 서울 용산구 회나무로 3
# 위도: 37.5385944, 경도: 126.9872881
# --------------------------------------------------
#
# [지역: 해방촌] 20. 올리에띠 가죽공방 · 공방
# 리뷰 수: 583
# 주소: 서울 용산구 녹사평대로54길 23-1 1층(목포집포자옆 통로입구)
# 위도: 37.5391822, 경도: 126.9885233
# --------------------------------------------------
#
# [지역: 해방촌] 21. 야간작업실 · 공방
# 리뷰 수: 24
# 주소: 서울 용산구 신흥로 121-1 1층 좌측
# 위도: 37.5445408, 경도: 126.9824875
# --------------------------------------------------
#
# [지역: 해방촌] 23. 아프로탱 · 공방
# 리뷰 수: 5
# 주소: 서울 용산구 녹사평대로46길 9 1층
# 위도: 37.5373969, 경도: 126.9874034
# --------------------------------------------------
#
# [지역: 해방촌] 25. 쾨닉 서울 · 전시관
# 리뷰 수: 353
# 주소: 서울 용산구 소월로38길 30-34 B1F
# 위도: 37.5440662, 경도: 126.9901678
# --------------------------------------------------
#
# [지역: 해방촌] 27. 디어. · 공방
# 리뷰 수: 193
# 주소: 서울 용산구 회나무로6길 19 지층
# 위도: 37.5380738, 경도: 126.9888796
# --------------------------------------------------
#
# [지역: 해방촌] 29. 와이아트스튜디오 · 공방
# 리뷰 수: 28
# 주소: 서울 용산구 녹사평대로46길 23 202호
# 위도: 37.5372666, 경도: 126.9881324
# --------------------------------------------------
#
# [지역: 해방촌] 30. 스토리지북앤필름 로터리점 · 독립서점
# 리뷰 수: 94
# 주소: 서울 용산구 신흥로36길 5 1층
# 위도: 37.5465138, 경도: 126.981956
# --------------------------------------------------
#
# [지역: 해방촌] 31. 벨리븐 · 독립서점
# 리뷰 수: 62
# 주소: 서울 용산구 회나무로12길 5 Beleben
# 위도: 37.5391361, 경도: 126.9895695
# --------------------------------------------------
#
# [지역: 해방촌] 32. 슈공방 · 공방
# 리뷰 수: 96
# 주소: 서울 용산구 회나무로13가길 11 1층
# 위도: 37.5408168, 경도: 126.9901879
# --------------------------------------------------
#
# [지역: 해방촌] 34. 실버키트하우스 · 공방
# 리뷰 수: 65
# 주소: 서울 용산구 신흥로36길 6 1층
# 위도: 37.5463196, 경도: 126.9818831
# --------------------------------------------------
#
# [지역: 해방촌] 35. 용산역사문화사회적협동조합 · 관람,체험
# 리뷰 수: 82
# 주소: 서울 용산구 신흥로36길 4 2층
# 위도: 37.5463972, 경도: 126.9817824
# --------------------------------------------------
#
# [지역: 해방촌] 36. 세라믹 베이커리 · 공방
# 리뷰 수: 6
# 주소: 서울 용산구 녹사평대로40나길 53 1층
# 위도: 37.5368836, 경도: 126.9887314
# --------------------------------------------------
#
# [지역: 해방촌] 41. 갤러리 이알디 · 갤러리,화랑
# 리뷰 수: 171
# 주소: 서울 용산구 회나무로13가길 25
# 위도: 37.5410914, 경도: 126.9909435
# --------------------------------------------------
#
# [지역: 해방촌] 43. 마시멜로우아트홀 · 공방
# 리뷰 수: 56
# 주소: 서울 용산구 회나무로25길 25 2층
# 위도: 37.540874, 경도: 126.990961
# --------------------------------------------------
#
# [지역: 해방촌] 45. 갤러리uhm · 갤러리,화랑
# 리뷰 수: 51
# 주소: 서울 용산구 두텁바위로60길 49 대원정사빌딩 본관 4층
# 위도: 37.5489161, 경도: 126.9833721
# --------------------------------------------------
#
# [지역: 해방촌] 47. 비체노 가죽공방 · 공방
# 리뷰 수: 633
# 주소: 서울 용산구 녹사평대로40다길 2 101호
# 위도: 37.534968, 경도: 126.9884789
# --------------------------------------------------
#
# [지역: 수유역] 1. 놀숲 수유점 · 만화방
# 리뷰 수: 358
# 주소: 서울 강북구 노해로8길 22 211호
# 위도: 37.6379915, 경도: 127.0242548
# --------------------------------------------------
#
# [지역: 수유역] 2. 큐브이스케이프 수유점 · 방탈출카페
# 리뷰 수: 681
# 주소: 서울 강북구 도봉로87길 11 2층
# 위도: 37.638337, 경도: 127.0248677
# --------------------------------------------------
#
# [지역: 수유역] 3. 더트랩 수유 방탈출 · 방탈출카페
# 리뷰 수: 1469
# 주소: 서울 강북구 도봉로 363 구봉빌딩 4층
# 위도: 37.63994710000001, 경도: 127.027246
# --------------------------------------------------
#
# [지역: 수유역] 4. 더홀릭보드게임카페 수유역점 · 보드카페
# 리뷰 수: 2884
# 주소: 서울 강북구 노해로8길 29 4층
# 위도: 37.6385329, 경도: 127.0241951
# --------------------------------------------------
#
# [지역: 수유역] 5. 모비딕 만화카페&가챠샵 · 만화방
# 리뷰 수: 531
# 주소: 서울 강북구 도봉로 350 삼주빌딩 4층
# 위도: 37.6385766, 경도: 127.0266946
# --------------------------------------------------
#
# [지역: 수유역] 6. 공자왈만화방 · 만화방
# 리뷰 수: 634
# 주소: 서울 강북구 노해로8길 29 현대크리스탈 5층
# 위도: 37.6385329, 경도: 127.0241951
# --------------------------------------------------
#
# [지역: 수유역] 7. 벌툰 파리지앵 수유역점 · 만화방
# 리뷰 수: 127
# 주소: 서울 강북구 한천로139길 42 2층 204호
# 위도: 37.638904, 경도: 127.0249021
# --------------------------------------------------
#
# [지역: 수유역] 8. 보드게임카페 레드버튼 수유역점 · 보드카페
# 리뷰 수: 1625
# 주소: 서울 강북구 한천로139길 42 3층 302호
# 위도: 37.638904, 경도: 127.0249021
# --------------------------------------------------
#
# [지역: 수유역] 9. 핑크핑영화룸카페 · 룸카페
# 리뷰 수: 90
# 주소: 서울 강북구 노해로8길 28 3층
# 위도: 37.638283, 경도: 127.024383
# --------------------------------------------------
#
# [지역: 수유역] 10. 리틀비틀 수유점 · 키즈카페,실내놀이터
# 리뷰 수: 404
# 주소: 서울 강북구 노해로 70 5층 리틀비틀키즈카페
# 위도: 37.6418278, 경도: 127.0226705
# --------------------------------------------------
#
# [지역: 수유역] 11. 럭키골프클럽 · 골프연습장
# 리뷰 수: 18
# 주소: 서울 강북구 한천로 1013 2층,3층
# 위도: 37.6384442, 경도: 127.0285952
# --------------------------------------------------
#
# [지역: 수유역] 12. 내맘대로 꾸미는 슬라임 · 슬라임카페
# 리뷰 수: 97
# 주소: 서울 강북구 삼양로 421
# 위도: 37.6410501, 경도: 127.016616
# --------------------------------------------------
#
# [지역: 수유역] 13. 수 파크스크린골프 · 파크골프장
# 리뷰 수: 13
# 주소: 서울 강북구 도봉로67길 18 . 3층 03호
# 위도: 37.6307808, 경도: 127.0229483
# --------------------------------------------------
#
# [지역: 수유역] 14. 키즈마루 · 키즈카페,실내놀이터
# 리뷰 수: 173
# 주소: 서울 강북구 삼양로 433 삼원빌딩 4층
# 위도: 37.64216529999999, 경도: 127.0162809
# --------------------------------------------------
#
# [지역: 수유역] 15. 쥬니버스 · 동물카페
# 리뷰 수: 264
# 주소: 서울 강북구 삼양로 447 지하1층 쥬니버스
# 위도: 37.64330560000001, 경도: 127.0159155
# --------------------------------------------------
#
# [지역: 수유역] 16. 수만화카페 · 만화방
# 리뷰 수: 115
# 주소: 서울 도봉구 도봉로 454 3층
# 위도: 37.6462157, 경도: 127.0337088
# --------------------------------------------------
#
# [지역: 수유역] 17. 수유재래시장 · 시장
# 리뷰 수: 802
# 주소: 서울 강북구 도봉로71길 26 수유재래시장
# 위도: 37.6314922, 경도: 127.0224643
# --------------------------------------------------
#
# [지역: 수유역] 18. 수유 펀치라인복싱 · 복싱,권투장
# 리뷰 수: 71
# 주소: 서울 강북구 삼양로 472 2층, 3층 펀치라인복싱
# 위도: 37.6453729, 경도: 127.0158044
# --------------------------------------------------
#
# [지역: 수유역] 19. 리우공방 · 공방
# 리뷰 수: 224
# 주소: 서울 강북구 삼양로 369 1층 리우공방
# 위도: 37.63638359999999, 경도: 127.0170743
# --------------------------------------------------
#
# [지역: 수유역] 23. 컨트롤비트코리아댄스학원 본점 · 댄스교육
# 리뷰 수: 200
# 주소: 서울 강북구 도봉로 369 2층
# 위도: 37.6403694, 경도: 127.0277078
# --------------------------------------------------
#
# [지역: 수유역] 24. 위드피아노 수유점 · 피아노
# 리뷰 수: 224
# 주소: 서울 강북구 덕릉로 101 보람빌딩 2층
# 위도: 37.6349962, 경도: 127.0250168
# --------------------------------------------------
#
# [지역: 수유역] 25. 고메스퀘어 수유점 · 일식,초밥뷔페
# 리뷰 수: 2852
# 주소: 서울 강북구 도봉로 308 9층
# 위도: 37.6356916, 경도: 127.0238173
# --------------------------------------------------
#
# [지역: 수유역] 26. 이로운날들 · 파티복대여
# 리뷰 수: 69
# 주소: 서울 도봉구 우이천로 284 J빌딩 4층
# 위도: 37.6436384, 경도: 127.0305779
# --------------------------------------------------
#
# [지역: 수유역] 29. 신매콤터 · 종합분식
# 리뷰 수: 1433
# 주소: 서울 강북구 오패산로 412
# 위도: 37.6374943, 경도: 127.026614
# --------------------------------------------------
#
# [지역: 수유역] 33. 조이앤플레이음악학원 창동점 · 피아노
# 리뷰 수: 205
# 주소: 서울 도봉구 우이천로20길 7 건영캐스빌 상가 206호
# 위도: 37.6414403, 경도: 127.0340343
# --------------------------------------------------
#
# [지역: 수유역] 36. 강북 북부시장 · 시장
# 리뷰 수: 80
# 주소: 서울 강북구 한천로123길 26
# 위도: 37.6362361, 경도: 127.0303452
# --------------------------------------------------
#
# [지역: 수유역] 39. 힐링뮤직아카데미 · 드럼
# 리뷰 수: 65
# 주소: 서울 강북구 한천로 1103 3층
# 위도: 37.6438657, 경도: 127.0209714
# --------------------------------------------------
#
# [지역: 수유역] 41. 피어나폴댄스 · 댄스교육
# 리뷰 수: 77
# 주소: 서울 강북구 오패산로77길 16 3층302호
# 위도: 37.6369781, 경도: 127.0256622
# --------------------------------------------------
#
# [지역: 수유역] 42. 스튜디오 퍼플제이 · 셀프,대여스튜디오
# 리뷰 수: 13
# 주소: 서울 강북구 덕릉로41길 56 유앤아이빌딩 5층
# 위도: 37.6344358, 경도: 127.0181455
# --------------------------------------------------
#
# [지역: 수유역] 44. 수유전통시장 · 시장
# 리뷰 수: 247
# 주소: 서울 강북구 도봉로67길 18 수유시장
# 위도: 37.6307808, 경도: 127.0229483
# --------------------------------------------------
#
# [지역: 수유역] 48. 스시노칸도 수유점 · 초밥,롤
# 리뷰 수: 7914
# 주소: 서울 강북구 한천로139나길 1 3층
# 위도: 37.6390657, 경도: 127.0252419
# --------------------------------------------------
#
# [지역: 경복궁] 1. 국립민속박물관 어린이박물관 · 박물관
# 리뷰 수: 1677
# 주소: 서울 종로구 삼청로 37
# 위도: 37.58084729999999, 경도: 126.9768515
# --------------------------------------------------
#
# [지역: 경복궁] 2. 국립고궁박물관 · 박물관
# 리뷰 수: 4441
# 주소: 서울 종로구 효자로 12 국립고궁박물관
# 위도: 37.5766084, 경도: 126.974951
# --------------------------------------------------
#
# [지역: 경복궁] 3. 국립민속박물관 · 박물관
# 리뷰 수: 5221
# 주소: 서울 종로구 삼청로 37
# 위도: 37.58084729999999, 경도: 126.9768515
# --------------------------------------------------
#
# [지역: 경복궁] 4. 경복궁 · 궁궐
# 리뷰 수: 35856
# 주소: 서울 종로구 사직로 161 경복궁
# 위도: 37.579617, 경도: 126.977041
# --------------------------------------------------
#
# [지역: 경복궁] 5. 대한민국역사박물관 · 박물관
# 리뷰 수: 4053
# 주소: 서울 종로구 세종대로 198 대한민국역사박물관
# 위도: 37.5739432, 경도: 126.9779299
# --------------------------------------------------
#
# [지역: 경복궁] 7. 현대화랑 · 갤러리,화랑
# 리뷰 수: 455
# 주소: 서울 종로구 삼청로 8
# 위도: 37.5766382, 경도: 126.9798457
# --------------------------------------------------
#
# [지역: 경복궁] 9. 국립현대미술관 서울 · 미술관
# 리뷰 수: 24827
# 주소: 서울 종로구 삼청로 30
# 위도: 37.5795117, 경도: 126.9805862
# --------------------------------------------------
#
# [지역: 경복궁] 12. 학고재 · 갤러리,화랑
# 리뷰 수: 2076
# 주소: 서울 종로구 삼청로 50
# 위도: 37.5803283, 경도: 126.9802958
# --------------------------------------------------
#
# [지역: 경복궁] 13. 통의동 보안여관 · 갤러리,화랑
# 리뷰 수: 1269
# 주소: 서울 종로구 효자로 33
# 위도: 37.57904389999999, 경도: 126.9736188
# --------------------------------------------------
#
# [지역: 경복궁] 15. 아트사이드 갤러리 · 갤러리,화랑
# 리뷰 수: 656
# 주소: 서울 종로구 자하문로6길 15 아트사이드 갤러리
# 위도: 37.5782277, 경도: 126.9729419
# --------------------------------------------------
#
# [지역: 경복궁] 16. 국제갤러리 · 갤러리,화랑
# 리뷰 수: 4720
# 주소: 서울 종로구 삼청로 54
# 위도: 37.5807226, 경도: 126.9808479
# --------------------------------------------------
#
# [지역: 경복궁] 19. 유스퀘이크 · 전시관
# 리뷰 수: 148
# 주소: 서울 종로구 효자로 25
# 위도: 37.5783286, 경도: 126.9736927
# --------------------------------------------------
#
# [지역: 경복궁] 21. 책방오늘 · 독립서점
# 리뷰 수: 477
# 주소: 서울 종로구 자하문로6길 11 1호
# 위도: 37.5781982, 경도: 126.972777
# --------------------------------------------------
#
# [지역: 경복궁] 22. 페레스프로젝트 · 갤러리,화랑
# 리뷰 수: 318
# 주소: 서울 종로구 율곡로1길 37 1층
# 위도: 37.5775789, 경도: 126.9804722
# --------------------------------------------------
#
# [지역: 경복궁] 25. 미앤갤러리 · 갤러리,화랑
# 리뷰 수: 56
# 주소: 서울 종로구 자하문로10길 13-1
# 위도: 37.5795256, 경도: 126.9723511
# --------------------------------------------------
#
# [지역: 경복궁] 26. 리안갤러리 서울 · 갤러리,화랑
# 리뷰 수: 233
# 주소: 서울 종로구 자하문로12길 9
# 위도: 37.5798204, 경도: 126.9719442
# --------------------------------------------------
#
# [지역: 경복궁] 27. 한복남 경복궁점 · 한복대여
# 리뷰 수: 3469
# 주소: 서울 종로구 사직로 133-5
# 위도: 37.5762335, 경도: 126.9733125
# --------------------------------------------------
#
# [지역: 경복궁] 29. 학고재 아트센터 · 갤러리,화랑
# 리뷰 수: 245
# 주소: 서울 종로구 삼청로 48-4
# 위도: 37.58024229999999, 경도: 126.9804411
# --------------------------------------------------
#
# [지역: 경복궁] 30. 지지배배한복 경복궁점 · 한복대여
# 리뷰 수: 1707
# 주소: 서울 종로구 자하문로2길 18 3층 지지배배
# 위도: 37.5763759, 경도: 126.9736739
# --------------------------------------------------
#
# [지역: 경복궁] 31. 참한복 & 스튜디오 · 한복대여
# 리뷰 수: 1480
# 주소: 서울 종로구 종로1길 55 경제통신사빌딩 2층
# 위도: 37.575338, 경도: 126.9788824
# --------------------------------------------------
#
# [지역: 경복궁] 32. 무서록 · 갤러리,화랑
# 리뷰 수: 76
# 주소: 서울 종로구 자하문로6길 12-16 2층
# 위도: 37.577861, 경도: 126.9725071
# --------------------------------------------------
#
# [지역: 경복궁] 33. 디아 컨템포러리 · 갤러리,화랑
# 리뷰 수: 18
# 주소: 서울 종로구 율곡로1길 37 2층
# 위도: 37.5775789, 경도: 126.9804722
# --------------------------------------------------
#
# [지역: 경복궁] 34. 한복남 프리미엄 · 한복대여
# 리뷰 수: 1072
# 주소: 서울 종로구 사직로 133-9 한복남 프리미엄
# 위도: 37.57619680000001, 경도: 126.9732928
# --------------------------------------------------
#
# [지역: 경복궁] 36. 나예한복 경복궁점 · 한복대여
# 리뷰 수: 333
# 주소: 서울 종로구 사직로 133-10 1층 나예한복
# 위도: 37.5763755, 경도: 126.9734463
# --------------------------------------------------
#
# [지역: 경복궁] 37. 아트스페이스3 · 갤러리,화랑
# 리뷰 수: 168
# 주소: 서울 종로구 효자로7길 23 지하 1층
# 위도: 37.5784234, 경도: 126.9733336
# --------------------------------------------------
#
# [지역: 경복궁] 40. 원데이한복 · 한복대여
# 리뷰 수: 274
# 주소: 서울 종로구 사직로 137 지하층
# 위도: 37.5760507, 경도: 126.9738485
# --------------------------------------------------
#
# [지역: 경복궁] 47. 한복소녀 · 한복대여
# 리뷰 수: 962
# 주소: 서울 종로구 자하문로2길 8 2층 서울 종로구 적선동 98)
# 위도: 37.5763674, 경도: 126.9731015
# --------------------------------------------------
#
# [지역: 경복궁] 48. 갤러리시몬 · 갤러리,화랑
# 리뷰 수: 184
# 주소: 서울 종로구 자하문로6길 20 갤러리시몬
# 위도: 37.5780759, 경도: 126.9732512
# --------------------------------------------------
#
# [지역: 경복궁] 49. 세계장신구박물관 · 박물관
# 리뷰 수: 26
# 주소: 서울 종로구 북촌로5나길 2 세계장신구박물관
# 위도: 37.580936, 경도: 126.9817903
# --------------------------------------------------
#
# [지역: 경복궁] 50. 별궁터한복 경복궁점 · 한복대여
# 리뷰 수: 335
# 주소: 서울 종로구 자하문로2길 7 2층
# 위도: 37.5765953, 경도: 126.9731545
# --------------------------------------------------
# 1번째 장소 클릭 실패
# 2번째 장소 클릭 실패
# 3번째 장소 클릭 실패
# 4번째 장소 클릭 실패
# CSV 저장 완료: sample_enjoy_results.csv
